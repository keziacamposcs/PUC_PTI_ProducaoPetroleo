# %% [markdown]
# ## **Importando Bibliotecas**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Métricas para análise
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# ## **Tratamento de Dados**

# %%
df = pd.read_csv('https://raw.githubusercontent.com/keziacamposcs/PUC_PTI_ProducaoPetroleo/main/producaoMar2022.csv', delimiter=';', error_bad_lines=False, engine='python')

#Consultando as 5 primeiras linhas
df.head()
# Out:
# <ipython-input-105-c8533df8eaf6>:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv('https://raw.githubusercontent.com/keziacamposcs/PUC_PTI_ProducaoPetroleo/main/producaoMar2022.csv', delimiter=';', error_bad_lines=False, engine='python')
#     Ano  Mês/Ano   Estado    Bacia   Campo         Poço Ambiente  \
# 0  2022  01/2022  Alagoas  Alagoas    PARU  4-ALS-39-AL      Mar
# 1  2022  01/2022    Bahia   Camamu  MANATI  7-MNT-1-BAS      Mar
# 2  2022  01/2022    Bahia   Camamu  MANATI  7-MNT-2-BAS      Mar
# 3  2022  01/2022    Bahia   Camamu  MANATI  7-MNT-3-BAS      Mar
# 4  2022  01/2022    Bahia   Camamu  MANATI  7-MNT-4-BAS      Mar
#
#                Instalação  Produção de Óleo (m³)  Produção de Condensado (m³)  \
# 0         Estação de Paru                    0.0                        438.0
# 1  PLATAFORMA DE MANATI 1                    0.0                        232.0
# 2  PLATAFORMA DE MANATI 1                    0.0                        236.0
# 3  PLATAFORMA DE MANATI 1                    0.0                        175.0
# 4  PLATAFORMA DE MANATI 1                    0.0                        245.0
#
#    ...  Produção de Gás Não Associado (Mm³)  Produção de Água (m³)  \
# 0  ...                                  0.0                 4443.0
# 1  ...                                  0.0                15534.0
# 2  ...                                  0.0                15523.0
# 3  ...                                  0.0                10426.0
# 4  ...                                  0.0                16445.0
#
#    Injeção de Gás (Mm³)  Injeção de Água para Recuperação Secundária (m³)  \
# 0                1913.0                                              28.0
# 1               88893.0                                              96.0
# 2                9251.0                                              96.0
# 3               60248.0                                              68.0
# 4               85832.0                                             110.0
#
#    Injeção de Água para Descarte (m³)  Injeção de Gás Carbônico (Mm³)  \
# 0                               935.0                             NaN
# 1                               315.0                             NaN
# 2                               249.0                             NaN
# 3                               815.0                             NaN
# 4                               188.0                             NaN
#
#    Injeção de Nitrogênio (Mm³)  Injeção de Vapor de Água (t)  \
# 0                          NaN                           NaN
# 1                          NaN                           NaN
# 2                          NaN                           NaN
# 3                          NaN                           NaN
# 4                          NaN                           NaN
#
#    Injeção de Polímeros (m³)  Injeção de Outros Fluidos (m³)
# 0                        NaN                             NaN
# 1                        NaN                             NaN
# 2                        NaN                             NaN
# 3                        NaN                             NaN
# 4                        NaN                             NaN
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Dividindo os dados por mês

# %%
df_jan = df.loc[df['Mês/Ano'] == '01/2022']
df_jan.head()
# Out:
#     Ano  Mês/Ano   Estado    Bacia   Campo         Poço Ambiente  \
# 0  2022  01/2022  Alagoas  Alagoas    PARU  4-ALS-39-AL      Mar
# 1  2022  01/2022    Bahia   Camamu  MANATI  7-MNT-1-BAS      Mar
# 2  2022  01/2022    Bahia   Camamu  MANATI  7-MNT-2-BAS      Mar
# 3  2022  01/2022    Bahia   Camamu  MANATI  7-MNT-3-BAS      Mar
# 4  2022  01/2022    Bahia   Camamu  MANATI  7-MNT-4-BAS      Mar
#
#                Instalação  Produção de Óleo (m³)  Produção de Condensado (m³)  \
# 0         Estação de Paru                    0.0                        438.0
# 1  PLATAFORMA DE MANATI 1                    0.0                        232.0
# 2  PLATAFORMA DE MANATI 1                    0.0                        236.0
# 3  PLATAFORMA DE MANATI 1                    0.0                        175.0
# 4  PLATAFORMA DE MANATI 1                    0.0                        245.0
#
#    ...  Produção de Gás Não Associado (Mm³)  Produção de Água (m³)  \
# 0  ...                                  0.0                 4443.0
# 1  ...                                  0.0                15534.0
# 2  ...                                  0.0                15523.0
# 3  ...                                  0.0                10426.0
# 4  ...                                  0.0                16445.0
#
#    Injeção de Gás (Mm³)  Injeção de Água para Recuperação Secundária (m³)  \
# 0                1913.0                                              28.0
# 1               88893.0                                              96.0
# 2                9251.0                                              96.0
# 3               60248.0                                              68.0
# 4               85832.0                                             110.0
#
#    Injeção de Água para Descarte (m³)  Injeção de Gás Carbônico (Mm³)  \
# 0                               935.0                             NaN
# 1                               315.0                             NaN
# 2                               249.0                             NaN
# 3                               815.0                             NaN
# 4                               188.0                             NaN
#
#    Injeção de Nitrogênio (Mm³)  Injeção de Vapor de Água (t)  \
# 0                          NaN                           NaN
# 1                          NaN                           NaN
# 2                          NaN                           NaN
# 3                          NaN                           NaN
# 4                          NaN                           NaN
#
#    Injeção de Polímeros (m³)  Injeção de Outros Fluidos (m³)
# 0                        NaN                             NaN
# 1                        NaN                             NaN
# 2                        NaN                             NaN
# 3                        NaN                             NaN
# 4                        NaN                             NaN
#
# [5 rows x 21 columns]

# %%
df_fev = df.loc[df['Mês/Ano'] == '02/2022']
df_fev.head()
# Out:
#        Ano  Mês/Ano   Estado    Bacia   Campo         Poço Ambiente  \
# 1772  2022  02/2022  Alagoas  Alagoas    PARU  4-ALS-39-AL      Mar
# 1773  2022  02/2022    Bahia   Camamu  MANATI  7-MNT-1-BAS      Mar
# 1774  2022  02/2022    Bahia   Camamu  MANATI  7-MNT-2-BAS      Mar
# 1775  2022  02/2022    Bahia   Camamu  MANATI  7-MNT-3-BAS      Mar
# 1776  2022  02/2022    Bahia   Camamu  MANATI  7-MNT-4-BAS      Mar
#
#                   Instalação  Produção de Óleo (m³)  \
# 1772         Estação de Paru                    0.0
# 1773  PLATAFORMA DE MANATI 1                    0.0
# 1774  PLATAFORMA DE MANATI 1                    0.0
# 1775  PLATAFORMA DE MANATI 1                    0.0
# 1776  PLATAFORMA DE MANATI 1                    0.0
#
#       Produção de Condensado (m³)  ...  Produção de Gás Não Associado (Mm³)  \
# 1772                        243.0  ...                                  0.0
# 1773                        193.0  ...                                  0.0
# 1774                        196.0  ...                                  0.0
# 1775                        146.0  ...                                  0.0
# 1776                        204.0  ...                                  0.0
#
#       Produção de Água (m³)  Injeção de Gás (Mm³)  \
# 1772                 2163.0               47713.0
# 1773                13132.0               62429.0
# 1774                13123.0               35597.0
# 1775                 8814.0               26659.0
# 1776                13902.0               72434.0
#
#       Injeção de Água para Recuperação Secundária (m³)  \
# 1772                                               5.0
# 1773                                              81.0
# 1774                                              81.0
# 1775                                              58.0
# 1776                                              93.0
#
#       Injeção de Água para Descarte (m³)  Injeção de Gás Carbônico (Mm³)  \
# 1772                              1454.0                             NaN
# 1773                               422.0                             NaN
# 1774                               365.0                             NaN
# 1775                               173.0                             NaN
# 1776                               146.0                             NaN
#
#       Injeção de Nitrogênio (Mm³)  Injeção de Vapor de Água (t)  \
# 1772                          NaN                           NaN
# 1773                          NaN                           NaN
# 1774                          NaN                           NaN
# 1775                          NaN                           NaN
# 1776                          NaN                           NaN
#
#       Injeção de Polímeros (m³)  Injeção de Outros Fluidos (m³)
# 1772                        NaN                             NaN
# 1773                        NaN                             NaN
# 1774                        NaN                             NaN
# 1775                        NaN                             NaN
# 1776                        NaN                             NaN
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Análise dos dados

# %%
#Todas as colunas do Data Frame
df_jan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1772 entries, 0 to 1771
# Data columns (total 21 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Ano                                               1772 non-null   int64
#  1   Mês/Ano                                           1772 non-null   object
#  2   Estado                                            1772 non-null   object
#  3   Bacia                                             1772 non-null   object
#  4   Campo                                             1772 non-null   object
#  5   Poço                                              1772 non-null   object
#  6   Ambiente                                          1772 non-null   object
#  7   Instalação                                        1772 non-null   object
#  8   Produção de Óleo (m³)                             1362 non-null   float64
#  9   Produção de Condensado (m³)                       1362 non-null   float64
#  10  Produção de Gás Associado (Mm³)                   1362 non-null   float64
#  11  Produção de Gás Não Associado (Mm³)               1362 non-null   float64
#  12  Produção de Água (m³)                             1362 non-null   float64
#  13  Injeção de Gás (Mm³)                              1138 non-null   float64
#  14  Injeção de Água para Recuperação Secundária (m³)  1138 non-null   float64
#  15  Injeção de Água para Descarte (m³)                1066 non-null   float64
#  16  Injeção de Gás Carbônico (Mm³)                    415 non-null    float64
#  17  Injeção de Nitrogênio (Mm³)                       414 non-null    float64
#  18  Injeção de Vapor de Água (t)                      412 non-null    float64
#  19  Injeção de Polímeros (m³)                         412 non-null    float64
#  20  Injeção de Outros Fluidos (m³)                    412 non-null    float64
# dtypes: float64(13), int64(1), object(7)
# memory usage: 304.6+ KB

# %%
#Todas as colunas do Data Frame
df_fev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1774 entries, 1772 to 3545
# Data columns (total 21 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Ano                                               1774 non-null   int64
#  1   Mês/Ano                                           1774 non-null   object
#  2   Estado                                            1774 non-null   object
#  3   Bacia                                             1774 non-null   object
#  4   Campo                                             1774 non-null   object
#  5   Poço                                              1774 non-null   object
#  6   Ambiente                                          1774 non-null   object
#  7   Instalação                                        1774 non-null   object
#  8   Produção de Óleo (m³)                             1359 non-null   float64
#  9   Produção de Condensado (m³)                       1359 non-null   float64
#  10  Produção de Gás Associado (Mm³)                   1359 non-null   float64
#  11  Produção de Gás Não Associado (Mm³)               1359 non-null   float64
#  12  Produção de Água (m³)                             1359 non-null   float64
#  13  Injeção de Gás (Mm³)                              1116 non-null   float64
#  14  Injeção de Água para Recuperação Secundária (m³)  1116 non-null   float64
#  15  Injeção de Água para Descarte (m³)                1046 non-null   float64
#  16  Injeção de Gás Carbônico (Mm³)                    418 non-null    float64
#  17  Injeção de Nitrogênio (Mm³)                       417 non-null    float64
#  18  Injeção de Vapor de Água (t)                      415 non-null    float64
#  19  Injeção de Polímeros (m³)                         415 non-null    float64
#  20  Injeção de Outros Fluidos (m³)                    415 non-null    float64
# dtypes: float64(13), int64(1), object(7)
# memory usage: 304.9+ KB

# %%
# agrupa os dados por campo e calcula a soma da produção de óleo em cada campo
grouped = df_jan.groupby('Estado')['Produção de Óleo (m³)'].sum()

# cria uma figura
fig, ax = plt.subplots()

# cria um gráfico em círculo com as somas da produção de óleo
ax.pie(grouped.values, labels=grouped.index, autopct='%1.1f%%')

# adiciona um título ao gráfico
ax.set_title('Distribuição da Produção de Óleo por Estado')

# mostra o gráfico na tela
plt.show()

# %%
# agrupa os dados por campo e calcula a soma da produção de óleo em cada campo
grouped = df_jan.groupby('Bacia')['Produção de Óleo (m³)'].sum()

# cria uma figura
fig, ax = plt.subplots()

# cria um gráfico em círculo com as somas da produção de óleo
ax.pie(grouped.values, labels=grouped.index, autopct='%1.1f%%')

# adiciona um título ao gráfico
ax.set_title('Distribuição da Produção de Óleo por Bacia')

# mostra o gráfico na tela
plt.show()

# %% [markdown]
# Substituindo os valores nulos pela média de cada coluna:

# %%
df_jan.fillna(df_jan.mean(), inplace=True)
df_jan.head()
# Out:
# <ipython-input-112-ae16b1c81d34>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_jan.fillna(df_jan.mean(), inplace=True)
# <ipython-input-112-ae16b1c81d34>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_jan.fillna(df_jan.mean(), inplace=True)
#     Ano  Mês/Ano   Estado    Bacia   Campo         Poço Ambiente  \
# 0  2022  01/2022  Alagoas  Alagoas    PARU  4-ALS-39-AL      Mar
# 1  2022  01/2022    Bahia   Camamu  MANATI  7-MNT-1-BAS      Mar
# 2  2022  01/2022    Bahia   Camamu  MANATI  7-MNT-2-BAS      Mar
# 3  2022  01/2022    Bahia   Camamu  MANATI  7-MNT-3-BAS      Mar
# 4  2022  01/2022    Bahia   Camamu  MANATI  7-MNT-4-BAS      Mar
#
#                Instalação  Produção de Óleo (m³)  Produção de Condensado (m³)  \
# 0         Estação de Paru                    0.0                        438.0
# 1  PLATAFORMA DE MANATI 1                    0.0                        232.0
# 2  PLATAFORMA DE MANATI 1                    0.0                        236.0
# 3  PLATAFORMA DE MANATI 1                    0.0                        175.0
# 4  PLATAFORMA DE MANATI 1                    0.0                        245.0
#
#    ...  Produção de Gás Não Associado (Mm³)  Produção de Água (m³)  \
# 0  ...                                  0.0                 4443.0
# 1  ...                                  0.0                15534.0
# 2  ...                                  0.0                15523.0
# 3  ...                                  0.0                10426.0
# 4  ...                                  0.0                16445.0
#
#    Injeção de Gás (Mm³)  Injeção de Água para Recuperação Secundária (m³)  \
# 0                1913.0                                              28.0
# 1               88893.0                                              96.0
# 2                9251.0                                              96.0
# 3               60248.0                                              68.0
# 4               85832.0                                             110.0
#
#    Injeção de Água para Descarte (m³)  Injeção de Gás Carbônico (Mm³)  \
# 0                               935.0                      640.493976
# 1                               315.0                      640.493976
# 2                               249.0                      640.493976
# 3                               815.0                      640.493976
# 4                               188.0                      640.493976
#
#    Injeção de Nitrogênio (Mm³)  Injeção de Vapor de Água (t)  \
# 0                   993.297101                    8482.26699
# 1                   993.297101                    8482.26699
# 2                   993.297101                    8482.26699
# 3                   993.297101                    8482.26699
# 4                   993.297101                    8482.26699
#
#    Injeção de Polímeros (m³)  Injeção de Outros Fluidos (m³)
# 0                 205.752427                             0.0
# 1                 205.752427                             0.0
# 2                 205.752427                             0.0
# 3                 205.752427                             0.0
# 4                 205.752427                             0.0
#
# [5 rows x 21 columns]

# %%
df_fev.fillna(df_fev.mean(), inplace=True)
df_fev.head()
# Out:
# <ipython-input-113-3faba22181cd>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_fev.fillna(df_fev.mean(), inplace=True)
# <ipython-input-113-3faba22181cd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fev.fillna(df_fev.mean(), inplace=True)
#        Ano  Mês/Ano   Estado    Bacia   Campo         Poço Ambiente  \
# 1772  2022  02/2022  Alagoas  Alagoas    PARU  4-ALS-39-AL      Mar
# 1773  2022  02/2022    Bahia   Camamu  MANATI  7-MNT-1-BAS      Mar
# 1774  2022  02/2022    Bahia   Camamu  MANATI  7-MNT-2-BAS      Mar
# 1775  2022  02/2022    Bahia   Camamu  MANATI  7-MNT-3-BAS      Mar
# 1776  2022  02/2022    Bahia   Camamu  MANATI  7-MNT-4-BAS      Mar
#
#                   Instalação  Produção de Óleo (m³)  \
# 1772         Estação de Paru                    0.0
# 1773  PLATAFORMA DE MANATI 1                    0.0
# 1774  PLATAFORMA DE MANATI 1                    0.0
# 1775  PLATAFORMA DE MANATI 1                    0.0
# 1776  PLATAFORMA DE MANATI 1                    0.0
#
#       Produção de Condensado (m³)  ...  Produção de Gás Não Associado (Mm³)  \
# 1772                        243.0  ...                                  0.0
# 1773                        193.0  ...                                  0.0
# 1774                        196.0  ...                                  0.0
# 1775                        146.0  ...                                  0.0
# 1776                        204.0  ...                                  0.0
#
#       Produção de Água (m³)  Injeção de Gás (Mm³)  \
# 1772                 2163.0               47713.0
# 1773                13132.0               62429.0
# 1774                13123.0               35597.0
# 1775                 8814.0               26659.0
# 1776                13902.0               72434.0
#
#       Injeção de Água para Recuperação Secundária (m³)  \
# 1772                                               5.0
# 1773                                              81.0
# 1774                                              81.0
# 1775                                              58.0
# 1776                                              93.0
#
#       Injeção de Água para Descarte (m³)  Injeção de Gás Carbônico (Mm³)  \
# 1772                              1454.0                       37.181818
# 1773                               422.0                       37.181818
# 1774                               365.0                       37.181818
# 1775                               173.0                       37.181818
# 1776                               146.0                       37.181818
#
#       Injeção de Nitrogênio (Mm³)  Injeção de Vapor de Água (t)  \
# 1772                   847.170264                   7971.120482
# 1773                   847.170264                   7971.120482
# 1774                   847.170264                   7971.120482
# 1775                   847.170264                   7971.120482
# 1776                   847.170264                   7971.120482
#
#       Injeção de Polímeros (m³)  Injeção de Outros Fluidos (m³)
# 1772                        0.0                             0.0
# 1773                        0.0                             0.0
# 1774                        0.0                             0.0
# 1775                        0.0                             0.0
# 1776                        0.0                             0.0
#
# [5 rows x 21 columns]

# %%
# agrupa os dados por campo e calcula a soma da produção de óleo em cada campo
grouped = df_jan.groupby('Bacia')['Produção de Óleo (m³)'].sum()

# cria uma figura
fig, ax = plt.subplots()

# cria um gráfico em círculo com as somas da produção de óleo
ax.pie(grouped.values, labels=grouped.index, autopct='%1.1f%%')

# adiciona um título ao gráfico
ax.set_title('Distribuição da Produção de Óleo por Campo')

# mostra o gráfico na tela
plt.show()

# %%
# agrupa os dados por campo e calcula a soma da produção de óleo em cada campo
grouped = df_jan.groupby('Estado')['Produção de Óleo (m³)'].sum()

# cria uma figura
fig, ax = plt.subplots()

# cria um gráfico em círculo com as somas da produção de óleo
ax.pie(grouped.values, labels=grouped.index, autopct='%1.1f%%')

# adiciona um título ao gráfico
ax.set_title('Distribuição da Produção de Óleo por Campo')

# mostra o gráfico na tela
plt.show()

# %% [markdown]
# ## **Correlação entre Dados**

# %%
# Ler os dados do arquivo CSV
df_corr = df_jan

# Selecionar apenas as colunas numéricas
numeric_cols = df_corr.select_dtypes(include='float64')

# Calcular a matriz de correlação
corr_matrix = numeric_cols.corr()

# Plotar o mapa de calor da matriz de correlação
sns.heatmap(corr_matrix, cmap='coolwarm', annot=True, fmt=".2f")
plt.show()

# %% [markdown]
# A **correlação** pode ser usada para determinar quais colunas são mais relevantes para fazer previsões, pois as variáveis com alta correlação tendem a ter uma relação mais forte com a variável alvo que estamos tentando prever.
#
# Isso pode ajudar na seleção de variáveis para o modelo de previsão, já que não é necessário incluir todas as colunas disponíveis, mas sim aquelas que têm maior impacto na variável alvo.
#
#
# Colunas definidas para previsão de **Produção de Óleo (m³)**:
#
# * Produção de Óleo
# * Produção de Condesado
# * Produção de gás não associado
# * Produção de Água

# %%
import matplotlib.pyplot as plt

# Crie um gráfico de dispersão
plt.scatter(df["Produção de Óleo (m³)"], df["Produção de Gás Não Associado (Mm³)"])

# Defina os títulos dos eixos x e y
plt.xlabel("Produção de Óleo (m³)")
plt.ylabel("Produção de Gás Não Associado (Mm³)")

# Defina o título do gráfico
plt.title("Dispersão entre Produção de Óleo e Produção de Gás Não Associado")

# Exiba o gráfico
plt.show()

# %% [markdown]
# ## **Dados para Treinamento**

# %%
df_jan = df_jan.drop(['Ano', 'Mês/Ano', 'Estado', 'Bacia', 'Campo', 'Poço', 'Ambiente','Instalação','Produção de Gás Associado (Mm³)', 'Injeção de Gás (Mm³)', 'Injeção de Água para Recuperação Secundária (m³)', 'Injeção de Água para Descarte (m³)', 'Injeção de Nitrogênio (Mm³)', 'Injeção de Vapor de Água (t)', 'Injeção de Polímeros (m³)', 'Injeção de Outros Fluidos (m³)', 'Injeção de Gás Carbônico (Mm³)'], axis=1)
df_jan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1772 entries, 0 to 1771
# Data columns (total 4 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Produção de Óleo (m³)                1772 non-null   float64
#  1   Produção de Condensado (m³)          1772 non-null   float64
#  2   Produção de Gás Não Associado (Mm³)  1772 non-null   float64
#  3   Produção de Água (m³)                1772 non-null   float64
# dtypes: float64(4)
# memory usage: 69.2 KB

# %% [markdown]
# ## **Dados para Teste**

# %%
df_fev = df_fev.drop(['Ano', 'Mês/Ano', 'Estado', 'Bacia', 'Campo', 'Poço', 'Ambiente','Instalação','Produção de Gás Associado (Mm³)', 'Injeção de Gás (Mm³)', 'Injeção de Água para Recuperação Secundária (m³)', 'Injeção de Água para Descarte (m³)', 'Injeção de Nitrogênio (Mm³)', 'Injeção de Vapor de Água (t)', 'Injeção de Polímeros (m³)', 'Injeção de Outros Fluidos (m³)', 'Injeção de Gás Carbônico (Mm³)'], axis=1)
df_fev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1774 entries, 1772 to 3545
# Data columns (total 4 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Produção de Óleo (m³)                1774 non-null   float64
#  1   Produção de Condensado (m³)          1774 non-null   float64
#  2   Produção de Gás Não Associado (Mm³)  1774 non-null   float64
#  3   Produção de Água (m³)                1774 non-null   float64
# dtypes: float64(4)
# memory usage: 69.3 KB

# %% [markdown]
# ## **Regressão Linear**

# %%
from sklearn.linear_model import LinearRegression

# %%
train_df_rl = df_jan
train_df_rl.head()
# Out:
#    Produção de Óleo (m³)  Produção de Condensado (m³)  \
# 0                    0.0                        438.0
# 1                    0.0                        232.0
# 2                    0.0                        236.0
# 3                    0.0                        175.0
# 4                    0.0                        245.0
#
#    Produção de Gás Não Associado (Mm³)  Produção de Água (m³)
# 0                                  0.0                 4443.0
# 1                                  0.0                15534.0
# 2                                  0.0                15523.0
# 3                                  0.0                10426.0
# 4                                  0.0                16445.0

# %%
test_df_rl = df_fev
test_df_rl.head()
# Out:
#       Produção de Óleo (m³)  Produção de Condensado (m³)  \
# 1772                    0.0                        243.0
# 1773                    0.0                        193.0
# 1774                    0.0                        196.0
# 1775                    0.0                        146.0
# 1776                    0.0                        204.0
#
#       Produção de Gás Não Associado (Mm³)  Produção de Água (m³)
# 1772                                  0.0                 2163.0
# 1773                                  0.0                13132.0
# 1774                                  0.0                13123.0
# 1775                                  0.0                 8814.0
# 1776                                  0.0                13902.0

# %%
# Separando as variáveis independentes da variável dependente
x_train = train_df_rl.drop('Produção de Óleo (m³)', axis=1)
y_train = train_df_rl['Produção de Óleo (m³)']

# %%
# Separando as variáveis independentes da variável dependente
x_test = test_df_rl.drop('Produção de Óleo (m³)', axis=1)
y_test = test_df_rl['Produção de Óleo (m³)']

# %%
# Criando o modelo
model_rl = LinearRegression()
model_rl.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# Fazendo a previsão
y_pred = model_rl.predict(x_test)

print(y_pred)
# Out:
# [ 913.91104358 1656.68904343 1656.18797311 ... 9629.72225282 9629.72225282
#   803.89904181]

# %%
# Avalia o desempenho do modelo
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)
print('MSE: ', mse)
print('RMSE: ', rmse)
print('R²: ', r2)
# Out:
# MSE:  98324757.95387545
# RMSE:  9915.88412366116
# R²:  0.7936746920759659

# %% [markdown]
# ## **Árvore de Decisão**

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
train_df_ad = df_jan
train_df_ad.head()
# Out:
#    Produção de Óleo (m³)  Produção de Condensado (m³)  \
# 0                    0.0                        438.0
# 1                    0.0                        232.0
# 2                    0.0                        236.0
# 3                    0.0                        175.0
# 4                    0.0                        245.0
#
#    Produção de Gás Não Associado (Mm³)  Produção de Água (m³)
# 0                                  0.0                 4443.0
# 1                                  0.0                15534.0
# 2                                  0.0                15523.0
# 3                                  0.0                10426.0
# 4                                  0.0                16445.0

# %%
test_df_ad = df_fev
test_df_ad.head()
# Out:
#       Produção de Óleo (m³)  Produção de Condensado (m³)  \
# 1772                    0.0                        243.0
# 1773                    0.0                        193.0
# 1774                    0.0                        196.0
# 1775                    0.0                        146.0
# 1776                    0.0                        204.0
#
#       Produção de Gás Não Associado (Mm³)  Produção de Água (m³)
# 1772                                  0.0                 2163.0
# 1773                                  0.0                13132.0
# 1774                                  0.0                13123.0
# 1775                                  0.0                 8814.0
# 1776                                  0.0                13902.0

# %%
# Separando as variáveis independentes da variável dependente
x_train = train_df_ad.drop('Produção de Óleo (m³)', axis=1)
y_train = train_df_ad['Produção de Óleo (m³)']

# %%
# Separando as variáveis independentes da variável dependente
x_test = test_df_ad.drop('Produção de Óleo (m³)', axis=1)
y_test = test_df_ad['Produção de Óleo (m³)']

# %%
# Criando o modelo
model_ad = DecisionTreeRegressor(random_state=42)
model_ad.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=42)

# %%
# Fazendo a previsão
y_pred = model_ad.predict(x_test)
print(y_pred)
# Out:
# [   0.    0.    0. ... 7206. 7206.    0.]

# %%
# Avalia o desempenho do modelo
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)
print('MSE: ', mse)
print('RMSE: ', rmse)
print('R²: ', r2)
# Out:
# MSE:  120562884.56525826
# RMSE:  10980.11313991155
# R²:  0.7470100633880459

# %% [markdown]
# ## **Random Forest**

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
train_df_rf = df_jan
train_df_rf.head()
# Out:
#    Produção de Óleo (m³)  Produção de Condensado (m³)  \
# 0                    0.0                        438.0
# 1                    0.0                        232.0
# 2                    0.0                        236.0
# 3                    0.0                        175.0
# 4                    0.0                        245.0
#
#    Produção de Gás Não Associado (Mm³)  Produção de Água (m³)
# 0                                  0.0                 4443.0
# 1                                  0.0                15534.0
# 2                                  0.0                15523.0
# 3                                  0.0                10426.0
# 4                                  0.0                16445.0

# %%
test_df_rf = df_fev
test_df_rf.head()
# Out:
#       Produção de Óleo (m³)  Produção de Condensado (m³)  \
# 1772                    0.0                        243.0
# 1773                    0.0                        193.0
# 1774                    0.0                        196.0
# 1775                    0.0                        146.0
# 1776                    0.0                        204.0
#
#       Produção de Gás Não Associado (Mm³)  Produção de Água (m³)
# 1772                                  0.0                 2163.0
# 1773                                  0.0                13132.0
# 1774                                  0.0                13123.0
# 1775                                  0.0                 8814.0
# 1776                                  0.0                13902.0

# %%
# Separando as variáveis independentes da variável dependente
x_train = train_df_rf.drop('Produção de Óleo (m³)', axis=1)
y_train = train_df_rf['Produção de Óleo (m³)']

# %%
# Separando as variáveis independentes da variável dependente
x_test = test_df_rf.drop('Produção de Óleo (m³)', axis=1)
y_test = test_df_rf['Produção de Óleo (m³)']

# %%
# Criando o modelo
model_rf = RandomForestRegressor(random_state=42)
model_rf.fit(x_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
# Fazendo a previsão
y_pred = model_rf.predict(x_test)
print(y_pred)
# Out:
# [   0.            0.            0.         ... 8766.27751101 8766.27751101
#     0.        ]

# %%
# Avalia o desempenho do modelo
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)
print('MSE: ', mse)
print('RMSE: ', rmse)
print('R²: ', r2)
# Out:
# MSE:  68400441.71655567
# RMSE:  8270.455955783555
# R²:  0.856468070778993

# %% [markdown]
# ## **Redes Neurais**

# %%
from sklearn.neural_network import MLPRegressor

# %%
train_df_rn = df_jan
train_df_rn.head()
# Out:
#    Produção de Óleo (m³)  Produção de Condensado (m³)  \
# 0                    0.0                        438.0
# 1                    0.0                        232.0
# 2                    0.0                        236.0
# 3                    0.0                        175.0
# 4                    0.0                        245.0
#
#    Produção de Gás Não Associado (Mm³)  Produção de Água (m³)
# 0                                  0.0                 4443.0
# 1                                  0.0                15534.0
# 2                                  0.0                15523.0
# 3                                  0.0                10426.0
# 4                                  0.0                16445.0

# %%
test_df_rn = df_fev
test_df_rn.head()
# Out:
#       Produção de Óleo (m³)  Produção de Condensado (m³)  \
# 1772                    0.0                        243.0
# 1773                    0.0                        193.0
# 1774                    0.0                        196.0
# 1775                    0.0                        146.0
# 1776                    0.0                        204.0
#
#       Produção de Gás Não Associado (Mm³)  Produção de Água (m³)
# 1772                                  0.0                 2163.0
# 1773                                  0.0                13132.0
# 1774                                  0.0                13123.0
# 1775                                  0.0                 8814.0
# 1776                                  0.0                13902.0

# %%
# Separando as variáveis independentes da variável dependente
x_train = train_df_rn.drop('Produção de Óleo (m³)', axis=1)
y_train = train_df_rn['Produção de Óleo (m³)']

# %%
# Separando as variáveis independentes da variável dependente
x_test = test_df_rn.drop('Produção de Óleo (m³)', axis=1)
y_test = test_df_rn['Produção de Óleo (m³)']

# %%
#Criando modelo de Redes Neurais
mlp = MLPRegressor(hidden_layer_sizes=(100, 100), activation='relu', solver='adam', max_iter=1000)

# %%
mlp.fit(x_train, y_train)
# Out:
# MLPRegressor(hidden_layer_sizes=(100, 100), max_iter=1000)

# %%
# Fazendo a previsão
y_pred = mlp.predict(x_test)
print(y_pred)
# Out:
# [ 107.88329418 1124.98136281 1122.93802613 ... 9998.63918398 9998.63918398
#    41.53340952]

# %%
# Avalia o desempenho do modelo
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)
print('MSE: ', mse)
print('RMSE: ', rmse)
print('R²: ', r2)
# Out:
# MSE:  80009457.91005647
# RMSE:  8944.800607618734
# R²:  0.8321076361268908

# %% [markdown]
# # **Micro**

# %% [markdown]
# ## **Recorte dos dados de Janeiro pelo Poço que teve maior produção**

# %%
df = pd.read_csv('https://raw.githubusercontent.com/keziacamposcs/PUC_PTI_ProducaoPetroleo/main/producaoMar2022.csv', delimiter=';', error_bad_lines=False, engine='python')
df_jan = df.loc[df['Mês/Ano'] == '01/2022']
df_jan.head()
# Out:
# <ipython-input-153-fc53d40d7e95>:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv('https://raw.githubusercontent.com/keziacamposcs/PUC_PTI_ProducaoPetroleo/main/producaoMar2022.csv', delimiter=';', error_bad_lines=False, engine='python')
#     Ano  Mês/Ano   Estado    Bacia   Campo         Poço Ambiente  \
# 0  2022  01/2022  Alagoas  Alagoas    PARU  4-ALS-39-AL      Mar
# 1  2022  01/2022    Bahia   Camamu  MANATI  7-MNT-1-BAS      Mar
# 2  2022  01/2022    Bahia   Camamu  MANATI  7-MNT-2-BAS      Mar
# 3  2022  01/2022    Bahia   Camamu  MANATI  7-MNT-3-BAS      Mar
# 4  2022  01/2022    Bahia   Camamu  MANATI  7-MNT-4-BAS      Mar
#
#                Instalação  Produção de Óleo (m³)  Produção de Condensado (m³)  \
# 0         Estação de Paru                    0.0                        438.0
# 1  PLATAFORMA DE MANATI 1                    0.0                        232.0
# 2  PLATAFORMA DE MANATI 1                    0.0                        236.0
# 3  PLATAFORMA DE MANATI 1                    0.0                        175.0
# 4  PLATAFORMA DE MANATI 1                    0.0                        245.0
#
#    ...  Produção de Gás Não Associado (Mm³)  Produção de Água (m³)  \
# 0  ...                                  0.0                 4443.0
# 1  ...                                  0.0                15534.0
# 2  ...                                  0.0                15523.0
# 3  ...                                  0.0                10426.0
# 4  ...                                  0.0                16445.0
#
#    Injeção de Gás (Mm³)  Injeção de Água para Recuperação Secundária (m³)  \
# 0                1913.0                                              28.0
# 1               88893.0                                              96.0
# 2                9251.0                                              96.0
# 3               60248.0                                              68.0
# 4               85832.0                                             110.0
#
#    Injeção de Água para Descarte (m³)  Injeção de Gás Carbônico (Mm³)  \
# 0                               935.0                             NaN
# 1                               315.0                             NaN
# 2                               249.0                             NaN
# 3                               815.0                             NaN
# 4                               188.0                             NaN
#
#    Injeção de Nitrogênio (Mm³)  Injeção de Vapor de Água (t)  \
# 0                          NaN                           NaN
# 1                          NaN                           NaN
# 2                          NaN                           NaN
# 3                          NaN                           NaN
# 4                          NaN                           NaN
#
#    Injeção de Polímeros (m³)  Injeção de Outros Fluidos (m³)
# 0                        NaN                             NaN
# 1                        NaN                             NaN
# 2                        NaN                             NaN
# 3                        NaN                             NaN
# 4                        NaN                             NaN
#
# [5 rows x 21 columns]

# %%
# Agrupando os dados pelo nome do poço e some a produção de óleo
df_jan_poco = df_jan.groupby('Poço')['Produção de Óleo (m³)'].sum()

# %%
df_jan_poco = df_jan_poco.sort_values(ascending=False)

print('O poço que produziu mais é:', df_jan_poco.index[0])
# Out:
# O poço que produziu mais é: 7-ATP-6-RJS

# %%
# Defina o nome do poço que você deseja filtrar
nome_do_poco = '7-ATP-6-RJS'

# Use o método .loc para selecionar apenas as linhas do DataFrame que correspondem a esse poço
poco_filtrado = df_jan.loc[df_jan['Poço'] == nome_do_poco]

# Crie um novo DataFrame contendo apenas as informações do poço filtrado
df_jan_poco = pd.DataFrame({
    'Ano': poco_filtrado['Ano'],
    'Mês/Ano': poco_filtrado['Mês/Ano'],
    'Estado': poco_filtrado['Estado'],
    'Bacia': poco_filtrado['Bacia'],
    'Campo': poco_filtrado['Campo'],
    'Poço': poco_filtrado['Poço'],
    'Ambiente': poco_filtrado['Ambiente'],
    'Instalação': poco_filtrado['Instalação'],
    'Produção de Óleo (m³)': poco_filtrado['Produção de Óleo (m³)'],
    'Produção de Condensado (m³)': poco_filtrado['Produção de Condensado (m³)'],
    'Produção de Gás Associado (Mm³)': poco_filtrado['Produção de Gás Associado (Mm³)'],
    'Produção de Gás Não Associado (Mm³)': poco_filtrado['Produção de Gás Não Associado (Mm³)'],
    'Produção de Água (m³)': poco_filtrado['Produção de Água (m³)'],
    'Injeção de Gás (Mm³)': poco_filtrado['Injeção de Gás (Mm³)'],
    'Injeção de Água para Recuperação Secundária (m³)': poco_filtrado['Injeção de Água para Recuperação Secundária (m³)'],
    'Injeção de Água para Descarte (m³)': poco_filtrado['Injeção de Água para Descarte (m³)'],
    'Injeção de Gás Carbônico (Mm³)': poco_filtrado['Injeção de Gás Carbônico (Mm³)'],
    'Injeção de Nitrogênio (Mm³)': poco_filtrado['Injeção de Nitrogênio (Mm³)'],
    'Injeção de Vapor de Água (t)': poco_filtrado['Injeção de Vapor de Água (t)'],
    'Injeção de Polímeros (m³)': poco_filtrado['Injeção de Polímeros (m³)'],
    'Injeção de Outros Fluidos (m³)': poco_filtrado['Injeção de Outros Fluidos (m³)']
})

df_jan_poco.head()
# Out:
#        Ano  Mês/Ano          Estado   Bacia            Campo         Poço  \
# 1100  2022  01/2022  Rio de Janeiro  Santos  ANC_NORTE_ATAPU  7-ATP-6-RJS
# 1191  2022  01/2022  Rio de Janeiro  Santos            ATAPU  7-ATP-6-RJS
# 1279  2022  01/2022  Rio de Janeiro  Santos   OESTE DE ATAPU  7-ATP-6-RJS
#
#      Ambiente    Instalação  Produção de Óleo (m³)  \
# 1100      Mar  Petrobras 70                 2450.0
# 1191      Mar  Petrobras 70               211539.0
# 1279      Mar  Petrobras 70                43928.0
#
#       Produção de Condensado (m³)  ...  Produção de Gás Não Associado (Mm³)  \
# 1100                      22942.0  ...                                530.0
# 1191                      96441.0  ...                              45831.0
# 1279                      75504.0  ...                               9517.0
#
#       Produção de Água (m³)  Injeção de Gás (Mm³)  \
# 1100                85836.0                   0.0
# 1191                57095.0                   0.0
# 1279                46287.0                   0.0
#
#       Injeção de Água para Recuperação Secundária (m³)  \
# 1100                                               0.0
# 1191                                               0.0
# 1279                                               0.0
#
#       Injeção de Água para Descarte (m³)  Injeção de Gás Carbônico (Mm³)  \
# 1100                                 NaN                             NaN
# 1191                                 NaN                             NaN
# 1279                                 NaN                             NaN
#
#       Injeção de Nitrogênio (Mm³)  Injeção de Vapor de Água (t)  \
# 1100                          NaN                           NaN
# 1191                          NaN                           NaN
# 1279                          NaN                           NaN
#
#       Injeção de Polímeros (m³)  Injeção de Outros Fluidos (m³)
# 1100                        NaN                             NaN
# 1191                        NaN                             NaN
# 1279                        NaN                             NaN
#
# [3 rows x 21 columns]

# %% [markdown]
# Definido o poço, é feito os mesmos tratamento de dados para então aplicar aos modelos de treinamento

# %%
# agrupa os dados por campo e calcula a soma da produção de óleo em cada campo
grouped = df_jan_poco.groupby('Campo')['Produção de Óleo (m³)'].sum()

# cria uma figura
fig, ax = plt.subplots()

# cria um gráfico em círculo com as somas da produção de óleo
ax.pie(grouped.values, labels=grouped.index, autopct='%1.1f%%')

# adiciona um título ao gráfico
ax.set_title('Distribuição da Produção de Óleo do Poço 7-ATP-6-RJS por Campo')

# mostra o gráfico na tela
plt.show()

# %%
df_jan_poco.fillna(df_jan_poco.mean(), inplace=True)
df_jan_poco.head()
# Out:
# <ipython-input-158-72096b601e52>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_jan_poco.fillna(df_jan_poco.mean(), inplace=True)
#        Ano  Mês/Ano          Estado   Bacia            Campo         Poço  \
# 1100  2022  01/2022  Rio de Janeiro  Santos  ANC_NORTE_ATAPU  7-ATP-6-RJS
# 1191  2022  01/2022  Rio de Janeiro  Santos            ATAPU  7-ATP-6-RJS
# 1279  2022  01/2022  Rio de Janeiro  Santos   OESTE DE ATAPU  7-ATP-6-RJS
#
#      Ambiente    Instalação  Produção de Óleo (m³)  \
# 1100      Mar  Petrobras 70                 2450.0
# 1191      Mar  Petrobras 70               211539.0
# 1279      Mar  Petrobras 70                43928.0
#
#       Produção de Condensado (m³)  ...  Produção de Gás Não Associado (Mm³)  \
# 1100                      22942.0  ...                                530.0
# 1191                      96441.0  ...                              45831.0
# 1279                      75504.0  ...                               9517.0
#
#       Produção de Água (m³)  Injeção de Gás (Mm³)  \
# 1100                85836.0                   0.0
# 1191                57095.0                   0.0
# 1279                46287.0                   0.0
#
#       Injeção de Água para Recuperação Secundária (m³)  \
# 1100                                               0.0
# 1191                                               0.0
# 1279                                               0.0
#
#       Injeção de Água para Descarte (m³)  Injeção de Gás Carbônico (Mm³)  \
# 1100                                 NaN                             NaN
# 1191                                 NaN                             NaN
# 1279                                 NaN                             NaN
#
#       Injeção de Nitrogênio (Mm³)  Injeção de Vapor de Água (t)  \
# 1100                          NaN                           NaN
# 1191                          NaN                           NaN
# 1279                          NaN                           NaN
#
#       Injeção de Polímeros (m³)  Injeção de Outros Fluidos (m³)
# 1100                        NaN                             NaN
# 1191                        NaN                             NaN
# 1279                        NaN                             NaN
#
# [3 rows x 21 columns]

# %%
df_jan = df_jan.drop(['Ano', 'Mês/Ano', 'Estado', 'Bacia', 'Campo', 'Poço', 'Ambiente','Instalação','Produção de Gás Associado (Mm³)', 'Injeção de Gás (Mm³)', 'Injeção de Água para Recuperação Secundária (m³)', 'Injeção de Água para Descarte (m³)', 'Injeção de Nitrogênio (Mm³)', 'Injeção de Vapor de Água (t)', 'Injeção de Polímeros (m³)', 'Injeção de Outros Fluidos (m³)', 'Injeção de Gás Carbônico (Mm³)'], axis=1)

# %%
df_jan_poco.fillna(df_jan_poco.mean(), inplace=True)
df_jan_poco.head()
# Out:
# <ipython-input-160-72096b601e52>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_jan_poco.fillna(df_jan_poco.mean(), inplace=True)
#        Ano  Mês/Ano          Estado   Bacia            Campo         Poço  \
# 1100  2022  01/2022  Rio de Janeiro  Santos  ANC_NORTE_ATAPU  7-ATP-6-RJS
# 1191  2022  01/2022  Rio de Janeiro  Santos            ATAPU  7-ATP-6-RJS
# 1279  2022  01/2022  Rio de Janeiro  Santos   OESTE DE ATAPU  7-ATP-6-RJS
#
#      Ambiente    Instalação  Produção de Óleo (m³)  \
# 1100      Mar  Petrobras 70                 2450.0
# 1191      Mar  Petrobras 70               211539.0
# 1279      Mar  Petrobras 70                43928.0
#
#       Produção de Condensado (m³)  ...  Produção de Gás Não Associado (Mm³)  \
# 1100                      22942.0  ...                                530.0
# 1191                      96441.0  ...                              45831.0
# 1279                      75504.0  ...                               9517.0
#
#       Produção de Água (m³)  Injeção de Gás (Mm³)  \
# 1100                85836.0                   0.0
# 1191                57095.0                   0.0
# 1279                46287.0                   0.0
#
#       Injeção de Água para Recuperação Secundária (m³)  \
# 1100                                               0.0
# 1191                                               0.0
# 1279                                               0.0
#
#       Injeção de Água para Descarte (m³)  Injeção de Gás Carbônico (Mm³)  \
# 1100                                 NaN                             NaN
# 1191                                 NaN                             NaN
# 1279                                 NaN                             NaN
#
#       Injeção de Nitrogênio (Mm³)  Injeção de Vapor de Água (t)  \
# 1100                          NaN                           NaN
# 1191                          NaN                           NaN
# 1279                          NaN                           NaN
#
#       Injeção de Polímeros (m³)  Injeção de Outros Fluidos (m³)
# 1100                        NaN                             NaN
# 1191                        NaN                             NaN
# 1279                        NaN                             NaN
#
# [3 rows x 21 columns]

# %% [markdown]
# ## **Dados para treinamento**

# %%
df_jan_poco = df_jan_poco.drop(['Ano', 'Mês/Ano', 'Estado', 'Bacia', 'Campo', 'Poço', 'Ambiente','Instalação','Produção de Gás Associado (Mm³)', 'Injeção de Gás (Mm³)', 'Injeção de Água para Recuperação Secundária (m³)', 'Injeção de Água para Descarte (m³)', 'Injeção de Nitrogênio (Mm³)', 'Injeção de Vapor de Água (t)', 'Injeção de Polímeros (m³)', 'Injeção de Outros Fluidos (m³)', 'Injeção de Gás Carbônico (Mm³)'], axis=1)
df_jan_poco.head()
# Out:
#       Produção de Óleo (m³)  Produção de Condensado (m³)  \
# 1100                 2450.0                      22942.0
# 1191               211539.0                      96441.0
# 1279                43928.0                      75504.0
#
#       Produção de Gás Não Associado (Mm³)  Produção de Água (m³)
# 1100                                530.0                85836.0
# 1191                              45831.0                57095.0
# 1279                               9517.0                46287.0

# %% [markdown]
# ## **Dados para teste**

# %%
df = pd.read_csv('https://raw.githubusercontent.com/keziacamposcs/PUC_PTI_ProducaoPetroleo/main/producaoMar2022.csv', delimiter=';', error_bad_lines=False, engine='python')
df_fev = df.loc[df['Mês/Ano'] == '02/2022']
df_fev.head()
# Out:
# <ipython-input-162-7c6abfaaf329>:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv('https://raw.githubusercontent.com/keziacamposcs/PUC_PTI_ProducaoPetroleo/main/producaoMar2022.csv', delimiter=';', error_bad_lines=False, engine='python')
#        Ano  Mês/Ano   Estado    Bacia   Campo         Poço Ambiente  \
# 1772  2022  02/2022  Alagoas  Alagoas    PARU  4-ALS-39-AL      Mar
# 1773  2022  02/2022    Bahia   Camamu  MANATI  7-MNT-1-BAS      Mar
# 1774  2022  02/2022    Bahia   Camamu  MANATI  7-MNT-2-BAS      Mar
# 1775  2022  02/2022    Bahia   Camamu  MANATI  7-MNT-3-BAS      Mar
# 1776  2022  02/2022    Bahia   Camamu  MANATI  7-MNT-4-BAS      Mar
#
#                   Instalação  Produção de Óleo (m³)  \
# 1772         Estação de Paru                    0.0
# 1773  PLATAFORMA DE MANATI 1                    0.0
# 1774  PLATAFORMA DE MANATI 1                    0.0
# 1775  PLATAFORMA DE MANATI 1                    0.0
# 1776  PLATAFORMA DE MANATI 1                    0.0
#
#       Produção de Condensado (m³)  ...  Produção de Gás Não Associado (Mm³)  \
# 1772                        243.0  ...                                  0.0
# 1773                        193.0  ...                                  0.0
# 1774                        196.0  ...                                  0.0
# 1775                        146.0  ...                                  0.0
# 1776                        204.0  ...                                  0.0
#
#       Produção de Água (m³)  Injeção de Gás (Mm³)  \
# 1772                 2163.0               47713.0
# 1773                13132.0               62429.0
# 1774                13123.0               35597.0
# 1775                 8814.0               26659.0
# 1776                13902.0               72434.0
#
#       Injeção de Água para Recuperação Secundária (m³)  \
# 1772                                               5.0
# 1773                                              81.0
# 1774                                              81.0
# 1775                                              58.0
# 1776                                              93.0
#
#       Injeção de Água para Descarte (m³)  Injeção de Gás Carbônico (Mm³)  \
# 1772                              1454.0                             NaN
# 1773                               422.0                             NaN
# 1774                               365.0                             NaN
# 1775                               173.0                             NaN
# 1776                               146.0                             NaN
#
#       Injeção de Nitrogênio (Mm³)  Injeção de Vapor de Água (t)  \
# 1772                          NaN                           NaN
# 1773                          NaN                           NaN
# 1774                          NaN                           NaN
# 1775                          NaN                           NaN
# 1776                          NaN                           NaN
#
#       Injeção de Polímeros (m³)  Injeção de Outros Fluidos (m³)
# 1772                        NaN                             NaN
# 1773                        NaN                             NaN
# 1774                        NaN                             NaN
# 1775                        NaN                             NaN
# 1776                        NaN                             NaN
#
# [5 rows x 21 columns]

# %%
# Defina o nome do poço que você deseja filtrar
nome_do_poco = '7-ATP-6-RJS'

# Use o método .loc para selecionar apenas as linhas do DataFrame que correspondem a esse poço
poco_filtrado = df_fev.loc[df_fev['Poço'] == nome_do_poco]

# Crie um novo DataFrame contendo apenas as informações do poço filtrado
df_fev_poco = pd.DataFrame({
    'Ano': poco_filtrado['Ano'],
    'Mês/Ano': poco_filtrado['Mês/Ano'],
    'Estado': poco_filtrado['Estado'],
    'Bacia': poco_filtrado['Bacia'],
    'Campo': poco_filtrado['Campo'],
    'Poço': poco_filtrado['Poço'],
    'Ambiente': poco_filtrado['Ambiente'],
    'Instalação': poco_filtrado['Instalação'],
    'Produção de Óleo (m³)': poco_filtrado['Produção de Óleo (m³)'],
    'Produção de Condensado (m³)': poco_filtrado['Produção de Condensado (m³)'],
    'Produção de Gás Associado (Mm³)': poco_filtrado['Produção de Gás Associado (Mm³)'],
    'Produção de Gás Não Associado (Mm³)': poco_filtrado['Produção de Gás Não Associado (Mm³)'],
    'Produção de Água (m³)': poco_filtrado['Produção de Água (m³)'],
    'Injeção de Gás (Mm³)': poco_filtrado['Injeção de Gás (Mm³)'],
    'Injeção de Água para Recuperação Secundária (m³)': poco_filtrado['Injeção de Água para Recuperação Secundária (m³)'],
    'Injeção de Água para Descarte (m³)': poco_filtrado['Injeção de Água para Descarte (m³)'],
    'Injeção de Gás Carbônico (Mm³)': poco_filtrado['Injeção de Gás Carbônico (Mm³)'],
    'Injeção de Nitrogênio (Mm³)': poco_filtrado['Injeção de Nitrogênio (Mm³)'],
    'Injeção de Vapor de Água (t)': poco_filtrado['Injeção de Vapor de Água (t)'],
    'Injeção de Polímeros (m³)': poco_filtrado['Injeção de Polímeros (m³)'],
    'Injeção de Outros Fluidos (m³)': poco_filtrado['Injeção de Outros Fluidos (m³)']
})

df_fev_poco.head()
# Out:
#        Ano  Mês/Ano          Estado   Bacia            Campo         Poço  \
# 2882  2022  02/2022  Rio de Janeiro  Santos  ANC_NORTE_ATAPU  7-ATP-6-RJS
# 2972  2022  02/2022  Rio de Janeiro  Santos            ATAPU  7-ATP-6-RJS
# 3060  2022  02/2022  Rio de Janeiro  Santos   OESTE DE ATAPU  7-ATP-6-RJS
#
#      Ambiente    Instalação  Produção de Óleo (m³)  \
# 2882      Mar  Petrobras 70                 1936.0
# 2972      Mar  Petrobras 70               167224.0
# 3060      Mar  Petrobras 70                34726.0
#
#       Produção de Condensado (m³)  ...  Produção de Gás Não Associado (Mm³)  \
# 2882                      93648.0  ...                                449.0
# 2972                      95247.0  ...                              38844.0
# 3060                      22297.0  ...                               8066.0
#
#       Produção de Água (m³)  Injeção de Gás (Mm³)  \
# 2882                93211.0                   0.0
# 2972                82107.0                   0.0
# 3060                58234.0                   0.0
#
#       Injeção de Água para Recuperação Secundária (m³)  \
# 2882                                               0.0
# 2972                                               0.0
# 3060                                               0.0
#
#       Injeção de Água para Descarte (m³)  Injeção de Gás Carbônico (Mm³)  \
# 2882                                 NaN                             NaN
# 2972                                 NaN                             NaN
# 3060                                 NaN                             NaN
#
#       Injeção de Nitrogênio (Mm³)  Injeção de Vapor de Água (t)  \
# 2882                          NaN                           NaN
# 2972                          NaN                           NaN
# 3060                          NaN                           NaN
#
#       Injeção de Polímeros (m³)  Injeção de Outros Fluidos (m³)
# 2882                        NaN                             NaN
# 2972                        NaN                             NaN
# 3060                        NaN                             NaN
#
# [3 rows x 21 columns]

# %%
df_fev_poco = df_fev_poco.drop(['Ano', 'Mês/Ano', 'Estado', 'Bacia', 'Campo', 'Poço', 'Ambiente','Instalação','Produção de Gás Associado (Mm³)', 'Injeção de Gás (Mm³)', 'Injeção de Água para Recuperação Secundária (m³)', 'Injeção de Água para Descarte (m³)', 'Injeção de Nitrogênio (Mm³)', 'Injeção de Vapor de Água (t)', 'Injeção de Polímeros (m³)', 'Injeção de Outros Fluidos (m³)', 'Injeção de Gás Carbônico (Mm³)'], axis=1)
df_fev_poco.head()
# Out:
#       Produção de Óleo (m³)  Produção de Condensado (m³)  \
# 2882                 1936.0                      93648.0
# 2972               167224.0                      95247.0
# 3060                34726.0                      22297.0
#
#       Produção de Gás Não Associado (Mm³)  Produção de Água (m³)
# 2882                                449.0                93211.0
# 2972                              38844.0                82107.0
# 3060                               8066.0                58234.0

# %% [markdown]
# ## **Regressão Linear**

# %%
train_df_rl = df_fev_poco
train_df_rl.head()
# Out:
#       Produção de Óleo (m³)  Produção de Condensado (m³)  \
# 2882                 1936.0                      93648.0
# 2972               167224.0                      95247.0
# 3060                34726.0                      22297.0
#
#       Produção de Gás Não Associado (Mm³)  Produção de Água (m³)
# 2882                                449.0                93211.0
# 2972                              38844.0                82107.0
# 3060                               8066.0                58234.0

# %%
test_df_rl = df_fev_poco
test_df_rl.head()
# Out:
#       Produção de Óleo (m³)  Produção de Condensado (m³)  \
# 2882                 1936.0                      93648.0
# 2972               167224.0                      95247.0
# 3060                34726.0                      22297.0
#
#       Produção de Gás Não Associado (Mm³)  Produção de Água (m³)
# 2882                                449.0                93211.0
# 2972                              38844.0                82107.0
# 3060                               8066.0                58234.0

# %%
# Separando as variáveis independentes da variável dependente
x_train = train_df_rl.drop('Produção de Óleo (m³)', axis=1)
y_train = train_df_rl['Produção de Óleo (m³)']

# %%
# Separando as variáveis independentes da variável dependente
x_test = test_df_rl.drop('Produção de Óleo (m³)', axis=1)
y_test = test_df_rl['Produção de Óleo (m³)']

# %%
# Criando o modelo
model_rl = LinearRegression()
model_rl.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# Fazendo a previsão
y_pred = model_rl.predict(x_test)
print(y_pred)
# Out:
# [  1936. 167224.  34726.]

# %%
# Avalia o desempenho do modelo
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)
print('MSE: ', mse)
print('RMSE: ', rmse)
print('R²: ', r2)
# Out:
# MSE:  2.064642808932357e-21
# RMSE:  4.543834073700708e-11
# R²:  1.0

# %% [markdown]
# ## **Árvore de Decisão**

# %%
train_df_ad = df_jan_poco
train_df_ad.head()
# Out:
#       Produção de Óleo (m³)  Produção de Condensado (m³)  \
# 1100                 2450.0                      22942.0
# 1191               211539.0                      96441.0
# 1279                43928.0                      75504.0
#
#       Produção de Gás Não Associado (Mm³)  Produção de Água (m³)
# 1100                                530.0                85836.0
# 1191                              45831.0                57095.0
# 1279                               9517.0                46287.0

# %%
test_df_ad = df_fev_poco
test_df_ad.head()
# Out:
#       Produção de Óleo (m³)  Produção de Condensado (m³)  \
# 2882                 1936.0                      93648.0
# 2972               167224.0                      95247.0
# 3060                34726.0                      22297.0
#
#       Produção de Gás Não Associado (Mm³)  Produção de Água (m³)
# 2882                                449.0                93211.0
# 2972                              38844.0                82107.0
# 3060                               8066.0                58234.0

# %%
# Separando as variáveis independentes da variável dependente
x_train = train_df_ad.drop('Produção de Óleo (m³)', axis=1)
y_train = train_df_ad['Produção de Óleo (m³)']

# %%
# Separando as variáveis independentes da variável dependente
x_test = test_df_ad.drop('Produção de Óleo (m³)', axis=1)
y_test = test_df_ad['Produção de Óleo (m³)']

# %%
# Criando o modelo
model_ad = DecisionTreeRegressor(random_state=42)
model_ad.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=42)

# %%
# Fazendo a previsão
y_pred = model_ad.predict(x_test)
print(y_pred)
# Out:
# [  2450. 211539.  43928.]

# %%
# Avalia o desempenho do modelo
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)
print('MSE: ', mse)
print('RMSE: ', rmse)
print('R²: ', r2)
# Out:
# MSE:  682920075.0
# RMSE:  26132.739523440705
# R²:  0.866242800871901

# %% [markdown]
# ## **Random Forest**

# %%
train_df_rf = df_jan_poco
train_df_rf.head()
# Out:
#       Produção de Óleo (m³)  Produção de Condensado (m³)  \
# 1100                 2450.0                      22942.0
# 1191               211539.0                      96441.0
# 1279                43928.0                      75504.0
#
#       Produção de Gás Não Associado (Mm³)  Produção de Água (m³)
# 1100                                530.0                85836.0
# 1191                              45831.0                57095.0
# 1279                               9517.0                46287.0

# %%
test_df_rf = df_fev_poco
test_df_rf.head()
# Out:
#       Produção de Óleo (m³)  Produção de Condensado (m³)  \
# 2882                 1936.0                      93648.0
# 2972               167224.0                      95247.0
# 3060                34726.0                      22297.0
#
#       Produção de Gás Não Associado (Mm³)  Produção de Água (m³)
# 2882                                449.0                93211.0
# 2972                              38844.0                82107.0
# 3060                               8066.0                58234.0

# %%
# Separando as variáveis independentes da variável dependente
x_train = train_df_rf.drop('Produção de Óleo (m³)', axis=1)
y_train = train_df_rf['Produção de Óleo (m³)']

# %%
# Separando as variáveis independentes da variável dependente
x_test = test_df_rf.drop('Produção de Óleo (m³)', axis=1)
y_test = test_df_rf['Produção de Óleo (m³)']

# %%
# Criando o modelo
model_rf = RandomForestRegressor(random_state=42)
model_rf.fit(x_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
# Fazendo a previsão
y_pred = model_rf.predict(x_test)
print(y_pred)
# Out:
# [ 80557.54 135784.22  54154.56]

# %%
# Avalia o desempenho do modelo
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)
print('MSE: ', mse)
print('RMSE: ', rmse)
print('R²: ', r2)
# Out:
# MSE:  2515758420.697866
# RMSE:  50157.33665873684
# R²:  0.5072618123936738

# %% [markdown]
# ## **Redes Neurais**

# %%
train_df_rn = df_jan_poco
train_df_rn.head()
# Out:
#       Produção de Óleo (m³)  Produção de Condensado (m³)  \
# 1100                 2450.0                      22942.0
# 1191               211539.0                      96441.0
# 1279                43928.0                      75504.0
#
#       Produção de Gás Não Associado (Mm³)  Produção de Água (m³)
# 1100                                530.0                85836.0
# 1191                              45831.0                57095.0
# 1279                               9517.0                46287.0

# %%
test_df_rn = df_fev_poco
test_df_rn.head()
# Out:
#       Produção de Óleo (m³)  Produção de Condensado (m³)  \
# 2882                 1936.0                      93648.0
# 2972               167224.0                      95247.0
# 3060                34726.0                      22297.0
#
#       Produção de Gás Não Associado (Mm³)  Produção de Água (m³)
# 2882                                449.0                93211.0
# 2972                              38844.0                82107.0
# 3060                               8066.0                58234.0

# %%
# Separando as variáveis independentes da variável dependente
x_train = train_df_rn.drop('Produção de Óleo (m³)', axis=1)
y_train = train_df_rn['Produção de Óleo (m³)']

# %%
# Separando as variáveis independentes da variável dependente
x_test = test_df_rn.drop('Produção de Óleo (m³)', axis=1)
y_test = test_df_rn['Produção de Óleo (m³)']

# %%
#Criando modelo de Redes Neurais
mlp = MLPRegressor(hidden_layer_sizes=(100, 100), activation='relu', solver='adam', max_iter=1000)

# %%
mlp.fit(x_train, y_train)
# Out:
# MLPRegressor(hidden_layer_sizes=(100, 100), max_iter=1000)

# %%
# Fazendo a previsão
y_pred = mlp.predict(x_test)
print(y_pred)
# Out:
# [  6876.91928928 163860.14079034  24543.47701416]

# %%
# Avalia o desempenho do modelo
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)
print('MSE: ', mse)
print('RMSE: ', rmse)
print('R²: ', r2)
# Out:
# MSE:  46470668.85425178
# RMSE:  6816.939845286283
# R²:  0.9908982225957348
